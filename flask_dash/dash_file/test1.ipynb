# %%
import datasource
import pandas as pd

lastest_data = datasource.lastest_datetime_data()
lastest_df = pd.DataFrame(lastest_data,columns=['站點名稱','更新時間','行政區','地址','總數','可借','可還'])
df1 = lastest_df.iloc[[1]]
[{"name": i, "id": i} for i in df1.columns]
# Out:
#                          站點名稱                 更新時間  行政區  \
# 0     YouBike2.0_捷運動物園站(2號出口)  2023-11-16 14:42:14  文山區
# 1           YouBike2.0_政大水岸電梯  2023-11-16 14:42:14  文山區
# 2             YouBike2.0_敦南山林  2023-11-16 14:42:14  文山區
# 3          YouBike2.0_景美污水抽水站  2023-11-16 14:42:14  文山區
# 4       YouBike2.0_萬和三號公園(北側)  2023-11-16 14:42:14  文山區
# ...                       ...                  ...  ...
# 1317       YouBike2.0_和平實小東北側  2023-11-26 21:25:06  大安區
# 1318     YouBike2.0_大安區健康服務中心  2023-11-26 21:25:06  大安區
# 1319        YouBike2.0_辛亥泰順街口  2023-11-26 21:25:16  大安區
# 1320          YouBike2.0_芳和國中  2023-11-26 21:25:16  大安區
# 1321        YouBike2.0_臥龍樂業街口  2023-11-26 21:25:16  大安區
#
#                          地址  總數  可借  可還
# 0                 新光路二段28號前  39   0  39
# 1                 政治大學水岸電梯旁  10   0  10
# 2     木柵路四段159巷16弄(社區出入口對側)  14   0  14
# 3             汀州路四段10號北側人行道  15   0  15
# 4             溪洲街107巷(公園北側)  13   0  13
# ...                     ...  ..  ..  ..
# 1317                 敦南街73號  13  11   2
# 1318               辛亥路三段15號  15   0  15
# 1319              辛亥泰順街口東南側  20   4  16
# 1320             臥龍街170號(前)  28  15  13
# 1321              臥龍街234-2號  41  28  13
#
# [1322 rows x 7 columns]

# %%
lastest_df1 = lastest_df.reset_index()
lastest_df1['站點名稱'] = lastest_df1['站點名稱'].map(lambda name:name[11:])

# %%
lastest_df1
